# %%
import os
from os import walk
import re
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline



class DataType: #User-defined Class
    def __init__(self, type):
        self.type = type
        
p1 = DataType("Ground-Truth")
p2 = DataType("Synthetic")



wdir = os.getcwd()


for f in os.listdir(wdir): # Iteration type forloop
    if f.endswith('.xlsx'):
        print(f)

spreadsheet = input('Specify spreadsheet path::')

if os.path.exists(spreadsheet): #Conditional
    print('')
    print('File path found.')
    
else:
    print('ERROR: File path not found.')

#C:\Users\calia\Documents\Book1.xlsx


print(spreadsheet)


data = pd.read_excel (spreadsheet, sheet_name='Sheet1') #FILE INPUT
df = pd.DataFrame(data, columns= ['FS ID', 'Left-Lateral-Ventricle', 'Left-Inf-Lat-Vent', 'Left-Cerebellum-White-Matter', 'Left-Cerebellum-Cortex', 'Left-Thalamus', 'Left-Caudate', 'Left-Putamen', 'Left-Pallidum', '3rd-Ventricle', '4th-Ventricle', 'Brain-Stem', 'Left-Hippocampus', 'Left-Amygdala', 'CSF', 'Left-Accumbens-area', 'Left-VentralDC', 'Left-vessel', 'Left-choroid-plexus', 'Right-Lateral-Ventricle', 'Right-Inf-Lat-Vent', 'Right-Cerebellum-White-Matter', 'Right-Cerebellum-Cortex', 'Right-Thalamus', 'Right-Caudate', 'Right-Putamen', 'Right-Pallidum', 'Right-Hippocampus', 'Right-Amygdala', 'Right-Accumbens-area', 'Right-VentralDC', 'Right-vessel', 'Right-choroid-plexus', '5th-Ventricle', 'WM-hypointensities', 'Left-WM-hypointensities', 'Right-WM-hypointensities', 'non-WM-hypointensities', 'Left-non-WM-hypointensities', 'Right-non-WM-hypointensities', 'Optic-Chiasm', 'CC_Posterior', 'CC_Mid_Posterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Anterior', 'BrainSegVol', 'BrainSegVolNotVent', 'lhCortexVol', 'rhCortexVol', 'CortexVol', 'lhCerebralWhiteMatterVol', 'rhCerebralWhiteMatterVol', 'CerebralWhiteMatterVol', 'SubCortGrayVol', 'TotalGrayVol', 'SupraTentorialVol', 'SupraTentorialVolNotVent', 'MaskVol', 'BrainSegVol-to-eTIV', 'MaskVol-to-eTIV', 'lhSurfaceHoles', 'rhSurfaceHoles', 'SurfaceHoles', 'EstimatedTotalIntraCranialVol']) #LIST
print(p1.type)
print(df)
# Out:
# covid_sfn_sheet.xlsx
# ou1neuroc003_ses01.xlsx
# Specify spreadsheet path:: C:\Users\calia\Documents\Book1.xlsx
# File path found.
# C:\Users\calia\Documents\Book1.xlsx
# Ground-Truth
#            FS ID  Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# 0   sub-C009orig                 36801.3             2039.2
# 1   sub-C010orig                 32947.0             2097.8
# 2   sub-C011orig                 12546.5              519.2
# 3   sub-C012orig                  8034.4              600.5
# 4   sub-C013orig                 21450.4              831.1
# 5   sub-C014orig                 23576.9             1834.8
# 6   sub-C017orig                 13400.1             1999.7
# 7  sub-JC001orig                 33028.1             2144.1
# 8  sub-JC002orig                 37132.4             2731.4
#
#    Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  Left-Thalamus  \
# 0                       10721.6                 47129.1         5651.2
# ...

# %%
data2 = pd.read_excel (spreadsheet, sheet_name='Sheet2')
df2 = pd.DataFrame(data2, columns= ['FS ID', 'Left-Lateral-Ventricle', 'Left-Inf-Lat-Vent', 'Left-Cerebellum-White-Matter', 'Left-Cerebellum-Cortex', 'Left-Thalamus', 'Left-Caudate', 'Left-Putamen', 'Left-Pallidum', '3rd-Ventricle', '4th-Ventricle', 'Brain-Stem', 'Left-Hippocampus', 'Left-Amygdala', 'CSF', 'Left-Accumbens-area', 'Left-VentralDC', 'Left-vessel', 'Left-choroid-plexus', 'Right-Lateral-Ventricle', 'Right-Inf-Lat-Vent', 'Right-Cerebellum-White-Matter', 'Right-Cerebellum-Cortex', 'Right-Thalamus', 'Right-Caudate', 'Right-Putamen', 'Right-Pallidum', 'Right-Hippocampus', 'Right-Amygdala', 'Right-Accumbens-area', 'Right-VentralDC', 'Right-vessel', 'Right-choroid-plexus', '5th-Ventricle', 'WM-hypointensities', 'Left-WM-hypointensities', 'Right-WM-hypointensities', 'non-WM-hypointensities', 'Left-non-WM-hypointensities', 'Right-non-WM-hypointensities', 'Optic-Chiasm', 'CC_Posterior', 'CC_Mid_Posterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Anterior', 'BrainSegVol', 'BrainSegVolNotVent', 'lhCortexVol', 'rhCortexVol', 'CortexVol', 'lhCerebralWhiteMatterVol', 'rhCerebralWhiteMatterVol', 'CerebralWhiteMatterVol', 'SubCortGrayVol', 'TotalGrayVol', 'SupraTentorialVol', 'SupraTentorialVolNotVent', 'MaskVol', 'BrainSegVol-to-eTIV', 'MaskVol-to-eTIV', 'lhSurfaceHoles', 'rhSurfaceHoles', 'SurfaceHoles', 'EstimatedTotalIntraCranialVol'])
print(p2.type)
print(df2)
# Out:
# Synthetic
#        FS ID  Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# 0   sub-C009                 35011.0             1181.6
# 1   sub-C010                 29768.1              804.7
# 2   sub-C011                 11841.5              685.8
# 3   sub-C012                  7811.8              430.5
# 4   sub-C013                 19364.4              799.1
# 5   sub-C014                 21377.0              818.3
# 6   sub-C017                 13639.2             1278.5
# 7  sub-JC001                 31122.7              432.1
# 8  sub-JC002                 34854.0             1785.9
#
#    Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  Left-Thalamus  \
# 0                       12014.8                 50171.1         4950.1
# 1                       15599.5                 41989.0         5572.9
# 2                       14522.0                 60306.5         6802.0
# 3                       14549.3                 59263.4         7997.2
# ...

# %%
df3 = pd.concat([df, df2])

m = ['FS ID', 'Left-Lateral-Ventricle', 'Left-Inf-Lat-Vent', 'Left-Cerebellum-White-Matter', 'Left-Cerebellum-Cortex', 'Left-Thalamus', 'Left-Caudate', 'Left-Putamen', 'Left-Pallidum', '3rd-Ventricle', '4th-Ventricle', 'Brain-Stem', 'Left-Hippocampus', 'Left-Amygdala', 'CSF', 'Left-Accumbens-area', 'Left-VentralDC', 'Left-vessel', 'Left-choroid-plexus', 'Right-Lateral-Ventricle', 'Right-Inf-Lat-Vent', 'Right-Cerebellum-White-Matter', 'Right-Cerebellum-Cortex', 'Right-Thalamus', 'Right-Caudate', 'Right-Putamen', 'Right-Pallidum', 'Right-Hippocampus', 'Right-Amygdala', 'Right-Accumbens-area', 'Right-VentralDC', 'Right-vessel', 'Right-choroid-plexus', '5th-Ventricle', 'WM-hypointensities', 'Left-WM-hypointensities', 'Right-WM-hypointensities', 'non-WM-hypointensities', 'Left-non-WM-hypointensities', 'Right-non-WM-hypointensities', 'Optic-Chiasm', 'CC_Posterior', 'CC_Mid_Posterior', 'CC_Central', 'CC_Mid_Anterior', 'CC_Anterior', 'BrainSegVol', 'BrainSegVolNotVent', 'lhCortexVol', 'rhCortexVol', 'CortexVol', 'lhCerebralWhiteMatterVol', 'rhCerebralWhiteMatterVol', 'CerebralWhiteMatterVol', 'SubCortGrayVol', 'TotalGrayVol', 'SupraTentorialVol', 'SupraTentorialVolNotVent', 'MaskVol', 'BrainSegVol-to-eTIV', 'MaskVol-to-eTIV', 'lhSurfaceHoles', 'rhSurfaceHoles', 'SurfaceHoles', 'EstimatedTotalIntraCranialVol']


l = df.corrwith(df2, axis =0)
for r in m:
    for w in l:
    
        print(r, 'r = ',w)
# Out:
# FS ID r =  0.9978964593043345
# FS ID r =  0.6296179167169026
# FS ID r =  0.19391859265274336
# FS ID r =  0.5916194755493932
# FS ID r =  0.6817402812866603
# FS ID r =  0.5401732792019952
# FS ID r =  0.7742202859559282
# FS ID r =  0.9576404351845432
# FS ID r =  0.9560514458749381
# FS ID r =  0.9430387597987383
# FS ID r =  0.9572203497627859
# FS ID r =  0.8690229711396124
# FS ID r =  0.8259796259153791
# FS ID r =  0.7235873295300919
# FS ID r =  0.6198326186821012
# FS ID r =  0.9067492410220774
# FS ID r =  0.3401390809522211
# FS ID r =  0.6174855201532797
# FS ID r =  0.9199967075111357
# FS ID r =  0.4623957921881025
# FS ID r =  -0.05157260266704674
# FS ID r =  0.8689192987671871
# FS ID r =  0.8431168797874801
# FS ID r =  0.6110278804660937
# FS ID r =  0.827117836182704
# FS ID r =  0.7207290372668823
# FS ID r =  0.8530952983785461
# FS ID r =  0.865754357759466
# FS ID r =  0.7562182773803324
# FS ID r =  0.8869314572145801
# FS ID r =  0.022008842362021032
# ...

# %%
col1 = df2['Left-Lateral-Ventricle'].corr(df['Left-Lateral-Ventricle'])
print(col1)
col2 = df2['Left-Inf-Lat-Vent'].corr(df['Left-Inf-Lat-Vent'])
print(col2)
col3 = df2['Left-Cerebellum-White-Matter'].corr(df['Left-Cerebellum-White-Matter'])
print(col3)
col4 = df2['Left-Cerebellum-Cortex'].corr(df['Left-Cerebellum-Cortex'])
print(col4)
col5 = df2['Left-Thalamus'].corr(df['Left-Thalamus'])
print(col5)
col6 = df2['Left-Caudate'].corr(df['Left-Caudate'])
print(col6)
col7 = df2['Left-Putamen'].corr(df['Left-Putamen'])
print(col7)
col8 = df2['Left-Pallidum'].corr(df['Left-Pallidum'])
print(col8)
col9 = df2['3rd-Ventricle'].corr(df['3rd-Ventricle'])
print(col9)
col10 = df2['4th-Ventricle'].corr(df['4th-Ventricle'])
print(col10)
col11 = df2['Brain-Stem'].corr(df['Brain-Stem'])
print(col11)
col12 = df2['Left-Hippocampus'].corr(df['Left-Hippocampus'])
print(col12)
col13 = df2['Left-Amygdala'].corr(df['Left-Amygdala'])
print(col13)
col14 = df2['CSF'].corr(df['CSF'])
print(col14)
col15 = df2['Left-Accumbens-area'].corr(df['Left-Accumbens-area'])
print(col15)
col16 = df2['Left-VentralDC'].corr(df['Left-VentralDC'])
print(col16)
col17 = df2['Left-vessel'].corr(df['Left-vessel'])
print(col17)
col18 = df2['Left-choroid-plexus'].corr(df['Left-choroid-plexus'])
print(col18)
col19 = df2['Right-Lateral-Ventricle'].corr(df['Right-Lateral-Ventricle'])
print(col19)
col20 = df2['Right-Inf-Lat-Vent'].corr(df['Right-Inf-Lat-Vent'])
print(col20)
col21 = df2['Right-Cerebellum-White-Matter'].corr(df['Right-Cerebellum-White-Matter'])
print(col21)
col22 = df2['Right-Thalamus'].corr(df['Right-Thalamus'])
print(col22)
col23 = df2['Right-Caudate'].corr(df['Right-Caudate'])
print(col23)
col24 = df2['Right-Putamen'].corr(df['Right-Putamen'])
print(col24)
col25 = df2['Right-Pallidum'].corr(df['Right-Pallidum'])
print(col25)
col26 = df2['Right-Hippocampus'].corr(df['Right-Hippocampus'])
print(col26)
col27 = df2['Right-Amygdala'].corr(df['Right-Amygdala'])
print(col27)
col28 = df2['Right-Accumbens-area'].corr(df['Right-Accumbens-area'])
print(col28)
col29 = df2['Right-VentralDC'].corr(df['Right-VentralDC'])
print(col29)
col30 = df2['Right-vessel'].corr(df['Right-vessel'])
print(col30)
col31 = df2['Right-choroid-plexus'].corr(df['Right-choroid-plexus'])
print(col31)
col32 = df2['5th-Ventricle'].corr(df['5th-Ventricle'])
print(col32)
col33 = df2['WM-hypointensities'].corr(df['WM-hypointensities'])
print(col33)
col34 = df2['Left-WM-hypointensities'].corr(df['Left-WM-hypointensities'])
print(col34)
col35 = df2['Right-WM-hypointensities'].corr(df['Right-WM-hypointensities'])
print(col35)
col36 = df2['non-WM-hypointensities'].corr(df['non-WM-hypointensities'])
print(col36)
col37 = df2['Left-non-WM-hypointensities'].corr(df['Left-non-WM-hypointensities'])
print(col37)
col38 = df2['Right-non-WM-hypointensities'].corr(df['Right-non-WM-hypointensities'])
print(col38)
col39 = df2['Optic-Chiasm'].corr(df['Optic-Chiasm'])
print(col39)
col40 = df2['CC_Posterior'].corr(df['CC_Posterior'])
print(col40)
col41 = df2['CC_Mid_Posterior'].corr(df['CC_Mid_Posterior'])
print(col41)
col42 = df2['CC_Central'].corr(df['CC_Central'])
print(col42)
col43 = df2['CC_Mid_Anterior'].corr(df['CC_Mid_Anterior'])
print(col43)
col44 = df2['CC_Anterior'].corr(df['CC_Anterior'])
print(col44)
col45 = df2['BrainSegVol'].corr(df['BrainSegVol'])
print(col45)
col47 = df2['BrainSegVolNotVent'].corr(df['BrainSegVolNotVent'])
print(col47)
col48 = df2['lhCortexVol'].corr(df['lhCortexVol'])
print(col48)
col49 = df2['rhCortexVol'].corr(df['rhCortexVol'])
print(col49)
col50 = df2['CortexVol'].corr(df['CortexVol'])
print(col50)
col51 = df2['lhCerebralWhiteMatterVol'].corr(df['lhCerebralWhiteMatterVol'])
print(col51)
col52 = df2['rhCerebralWhiteMatterVol'].corr(df['rhCerebralWhiteMatterVol'])
print(col52)
col53 = df2['CerebralWhiteMatterVol'].corr(df['CerebralWhiteMatterVol'])
print(col53)
col54 = df2['SubCortGrayVol'].corr(df['SubCortGrayVol'])
print(col54)
col55 = df2['TotalGrayVol'].corr(df['TotalGrayVol'])
print(col55)
col56 = df2['SupraTentorialVol'].corr(df['SupraTentorialVol'])
print(col56)
col57 = df2['SupraTentorialVolNotVent'].corr(df['SupraTentorialVolNotVent'])
print(col57)
col58 = df2['MaskVol'].corr(df['MaskVol'])
print(col58)
col59 = df2['BrainSegVol-to-eTIV'].corr(df['BrainSegVol-to-eTIV'])
print(col59)
col60 = df2['MaskVol-to-eTIV'].corr(df['MaskVol-to-eTIV'])
print(col60)
col61 = df2['lhSurfaceHoles'].corr(df['lhSurfaceHoles'])
print(col61)
col62 = df2['rhSurfaceHoles'].corr(df['rhSurfaceHoles'])
print(col62)
col63 = df2['SurfaceHoles'].corr(df['SurfaceHoles'])
print(col63)
col64 = df2['lhSurfaceHoles'].corr(df['lhSurfaceHoles'])
print(col64)
col65 = df2['EstimatedTotalIntraCranialVol'].corr(df['EstimatedTotalIntraCranialVol'])
print(col65)
# Out:
# 0.9978964593043345
# 0.6296179167169026
# 0.19391859265274336
# 0.5916194755493932
# 0.6817402812866603
# 0.5401732792019952
# 0.7742202859559282
# 0.9576404351845433
# 0.9560514458749381
# 0.9430387597987385
# 0.9572203497627859
# 0.8690229711396122
# 0.8259796259153792
# 0.723587329530092
# 0.6198326186821012
# 0.9067492410220778
# 0.3401390809522211
# 0.6174855201532798
# 0.919996707511136
# 0.46239579218810245
# -0.051572602667046656
# 0.8431168797874802
# 0.6110278804660938
# 0.8271178361827042
# 0.7207290372668825
# 0.8530952983785459
# 0.865754357759466
# 0.7562182773803323
# 0.8869314572145801
# 0.022008842362021056
# 0.17198327693138654
# nan
# 0.6776447835272948
# nan
# nan
# -0.2998688733785714
# nan
# nan
# 0.1404646204253689
# -0.29246438052615586
# 0.4348732711473234
# 0.12791315164390324
# 0.26223576381550323
# -0.6686830808172635
# 0.9247003471508488
# 0.9428948183241049
# 0.9468468411493176
# 0.9709378811709803
# 0.9702785673749632
# 0.8718390650906315
# ...

# %%
X = df2['EstimatedTotalIntraCranialVol'].astype('int64')
Y = df['EstimatedTotalIntraCranialVol'].astype('int64')


def best_fit(X, Y): #User-defined function

    xbar = sum(X)/len(X)
    ybar = sum(Y)/len(Y)
    n = len(X) # or len(Y)

    numer = sum(xi*yi for xi,yi in zip(X, Y)) - n * xbar * ybar
    denum = sum(xi**2 for xi in X) - n * xbar**2

    b = numer / denum
    a = ybar - b * xbar

    print('best fit line:\ny = {:.2f} + {:.2f}x'.format(a, b))

    return a, b

# solution

a, b = best_fit(X, Y)
fig = plt.figure()
ax = fig.add_subplot(111)
plt.ticklabel_format(style='plain')
yfit = [a + b * xi for xi in X]
ax.set_xlabel('Ground-Truth', color ='red')
ax.set_ylabel('Synthetic', color ='blue')
plt.scatter(X, Y, c='red')
plt.scatter(Y, X, c ='blue')
plt.plot(X, yfit)
plt.grid()
plt.title('EstimatedTotalIntraCranialVol')
plt.savefig('Correlation.png') #Output
plt.show()
# Out:
# best fit line:
# y = 168526.56 + 0.84x
